# %%
import subprocess

notebooks = [
    "1_extract_api_to_landing.ipynb",
    "2_landing_to_staging.ipynb",
    "3_staging_to_silver.ipynb",
    "4_staging_to_links.ipynb"
]

for nb in notebooks:
    print(f"Running {nb}...")
    subprocess.run(["jupyter", "nbconvert", "--to", "notebook", "--execute", nb], check=True)
    print(f"{nb} completed successfully")
# Out:
# Running 1_extract_api_to_landing.ipynb...
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 12
#      10 for nb in notebooks:
#      11     print(f"Running {nb}...")
# ---> 12     subprocess.run(["jupyter", "nbconvert", "--to", "notebook", "--execute", nb], check=True)
#      13     print(f"{nb} completed successfully")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:577, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     575     retcode = process.poll()
#     576     if check and retcode:
# --> 577         raise CalledProcessError(retcode, process.args,
#     578                                  output=stdout, stderr=stderr)
#     579 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# ...
